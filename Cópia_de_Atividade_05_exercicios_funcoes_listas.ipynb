# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabriela-Leiros/2024.1-Algoritmos-e-Estruturas-de-Dados-Gabriela-Leiros/blob/main/C%C3%B3pia_de_Atividade_05_exercicios_funcoes_listas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive  # Tratar Google Drive
import os                       # Acessar comandos do SO
import importlib.util           # Importação do arquivo
import unittest                 # Realizar os testes unitários

# Montando a pasta no Google Drive
drive.mount('/content/drive')

# Navegar para o diretório de destino
os.chdir('/content/drive/MyDrive/Colab Notebooks/2024.1Algoritmos_e_estruturas_de_dados')

# Função para perguntar ao usuário o caminho do arquivo no Google Drive
def obter_caminho_arquivo():
    caminho = input("Digite o caminho completo do arquivo no Google Drive (ex: '/content/drive/MyDrive/Colab Notebooks/2024.1Algoritmos_e_estruturas_de_dados.ipynb'): ")
    print(f"O caminho fornecido foi: {caminho}")
    return caminho

# Converter notebook para script Python e importar o módulo
def importar_modulo(caminho_notebook):
    # Converter o notebook para um script Python
    # !jupyter nbconvert --to script "{caminho_notebook}"

    # Substituir a extensão '.ipynb' por '.py' para localizar o arquivo convertido
    caminho_py = caminho_notebook.replace('.ipynb', '.py')

    # Caso o arquivo tenha sido gerado como '.txt', renomeie para '.py'
    if os.path.exists(caminho_py.replace('.py', '.txt')):
        os.rename(caminho_py.replace('.py', '.txt'), caminho_py)

    # Importar o script Python gerado
    spec = importlib.util.spec_from_file_location("module", caminho_py)
    modulo = importlib.util.module_from_spec(spec)
    spec.loader.exec_module(modulo)
    return modulo

#importar ja com caminhos
palindromo_module = importar_modulo("/content/drive/MyDrive/Colab Notebooks/2024.1Algoritmos_e_estruturas_de_dados/Atividade_05_palindromo_.ipynb")
contagem_module = importar_modulo("/content/drive/MyDrive/Colab Notebooks/2024.1Algoritmos_e_estruturas_de_dados/Atividade_05_contagem.ipynb")
inverter_module = importar_modulo("/content/drive/MyDrive/Colab Notebooks/2024.1Algoritmos_e_estruturas_de_dados/Atividade_05_inverter.ipynb")
converter_module = importar_modulo("/content/drive/MyDrive/Colab Notebooks/2024.1Algoritmos_e_estruturas_de_dados/Atividade_05_converter.ipynb")
contar_module = importar_modulo("/content/drive/MyDrive/Colab Notebooks/2024.1Algoritmos_e_estruturas_de_dados/Atividade_05_converter.ipynb")


# Importar os módulos
#palindromo_module = importar_modulo(obter_caminho_arquivo())
#contagem_module = importar_modulo(obter_caminho_arquivo())
#inverter_module = importar_modulo(obter_caminho_arquivo())
#converter_module = importar_modulo(obter_caminho_arquivo())
#contar_module = importar_modulo(obter_caminho_arquivo())

# Testes Unificados
class TestListaDeExercicios(unittest.TestCase):

    # Testes para o palíndromo
    def test_palindromo_simples(self):
        self.assertTrue(palindromo_module.eh_palindromo("radar"))

    def test_palindromo_com_espacos(self):
        self.assertTrue(palindromo_module.eh_palindromo("A man a plan a canal Panama"))

    def test_nao_palindromo(self):
        self.assertFalse(palindromo_module.eh_palindromo("algoritmo"))

    # Testes para contagem de palavras
    def test_contagem_palavra(self):
        with open("teste.txt", "w") as f:
            f.write("Ola mundo. O mundo é grande.")
        self.assertEqual(contagem_module.contar_palavra("teste.txt", "mundo"), 2)

    def test_palavra_nao_presente(self):
        with open("teste.txt", "w") as f:
            f.write("Ola universo.")
        self.assertEqual(contagem_module.contar_palavra("teste.txt", "mundo"), 0)

    # Testes para inverter string
    def test_inverter_simples(self):
        self.assertEqual(inverter_module.inverter_string("algoritmo"), "omtirgola")

    def test_inverter_com_espacos(self):
        self.assertEqual(inverter_module.inverter_string("estrutura de dados"), "sodad ed aruturtse")

    def test_inverter_vazio(self):
        self.assertEqual(inverter_module.inverter_string(""), "")

    # Testes para converter para maiúsculas
    def test_converter(self):
        with open("entrada.txt", "w") as f:
            f.write("Python é divertido.")
        converter_module.converter_para_maiusculas("entrada.txt", "saida.txt")
        with open("saida.txt", "r") as f:
            conteudo = f.read()
        self.assertEqual(conteudo, "PYTHON É DIVERTIDO.")

    # Testes para contar caracteres
    def test_contagem_simples(self):
        self.assertEqual(contar_module.contar_caracteres("abcabc"), {'a': 2, 'b': 2, 'c': 2})

    def test_contagem_com_espacos(self):
        self.assertEqual(contar_module.contar_caracteres("a b c a b c"), {'a': 2, ' ': 5, 'b': 2, 'c': 2})

    def test_contagem_vazio(self):
        self.assertEqual(contar_module.contar_caracteres(""), {})

if __name__ == '__main__':
    unittest.main(argv=[''], verbosity=2, exit=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Colab Notebooks/2024.1Algoritmos_e_estruturas_de_dados/Atividade_05_palindromo_.ipynb to script
# [NbConvertApp] Writing 977 bytes to /content/drive/MyDrive/Colab Notebooks/2024.1Algoritmos_e_estruturas_de_dados/Atividade_05_palindromo_.txt
# Insira um nome: radar
# True
# Insira um nome: a man a plan a canal  panama
# True
# Insira um nome: algoritmo
# False
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Colab Notebooks/2024.1Algoritmos_e_estruturas_de_dados/Atividade_05_contagem.ipynb to script
# [NbConvertApp] Writing 583 bytes to /content/drive/MyDrive/Colab Notebooks/2024.1Algoritmos_e_estruturas_de_dados/Atividade_05_contagem.txt
# Insira uma palavra: Ola mundo. O mundo é grande.
# A palavra 'Ola mundo. O mundo é grande.' aparece 0 vezes no arquivo.
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Colab Notebooks/2024.1Algoritmos_e_estruturas_de_dados/Atividade_05_inverter.ipynb to script
# [NbConvertApp] Writing 267 bytes to /content/drive/MyDrive/Colab Notebooks/2024.1Algoritmos_e_estruturas_de_dados/Atividade_05_inverter.txt
# Digite uma palavra: Ola universo.
# A palavra é: .osrevinu alO
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Colab Notebooks/2024.1Algoritmos_e_estruturas_de_dados/Atividade_05_converter.ipynb to script
# [NbConvertApp] Writing 465 bytes to /content/drive/MyDrive/Colab Notebooks/2024.1Algoritmos_e_estruturas_de_dados/Atividade_05_converter.txt
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Colab Notebooks/2024.1Algoritmos_e_estruturas_de_dados/Atividade_05_converter.ipynb to script
# [NbConvertApp] Writing 465 bytes to /content/drive/MyDrive/Colab Notebooks/2024.1Algoritmos_e_estruturas_de_dados/Atividade_05_converter.txt
# test_contagem_com_espacos (__main__.TestListaDeExercicios) ... ERROR
# test_contagem_palavra (__main__.TestListaDeExercicios) ... ok
# test_contagem_simples (__main__.TestListaDeExercicios) ... ERROR
# test_contagem_vazio (__main__.TestListaDeExercicios) ... ERROR
# test_converter (__main__.TestListaDeExercicios) ... ok
# test_inverter_com_espacos (__main__.TestListaDeExercicios) ...
# A palavra é: .osrevinu alO
# FAIL
# test_inverter_simples (__main__.TestListaDeExercicios) ... FAIL
# test_inverter_vazio (__main__.TestListaDeExercicios) ... FAIL
# test_nao_palindromo (__main__.TestListaDeExercicios) ... ok
# test_palavra_nao_presente (__main__.TestListaDeExercicios) ... ok
# test_palindromo_com_espacos (__main__.TestListaDeExercicios) ... ok
# test_palindromo_simples (__main__.TestListaDeExercicios) ... ok
#
# ======================================================================
# ERROR: test_contagem_com_espacos (__main__.TestListaDeExercicios)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-5-233e9ae035d0>", line 99, in test_contagem_com_espacos
#     self.assertEqual(contar_module.contar_caracteres("a b c a b c"), {'a': 2, ' ': 5, 'b': 2, 'c': 2})
# AttributeError: module 'module' has no attribute 'contar_caracteres'
#
# ======================================================================
# ERROR: test_contagem_simples (__main__.TestListaDeExercicios)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-5-233e9ae035d0>", line 96, in test_contagem_simples
#     self.assertEqual(contar_module.contar_caracteres("abcabc"), {'a': 2, 'b': 2, 'c': 2})
# AttributeError: module 'module' has no attribute 'contar_caracteres'
#
# ======================================================================
# ERROR: test_contagem_vazio (__main__.TestListaDeExercicios)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-5-233e9ae035d0>", line 102, in test_contagem_vazio
#     self.assertEqual(contar_module.contar_caracteres(""), {})
# AttributeError: module 'module' has no attribute 'contar_caracteres'
#
# ======================================================================
# FAIL: test_inverter_com_espacos (__main__.TestListaDeExercicios)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-5-233e9ae035d0>", line 80, in test_inverter_com_espacos
#     self.assertEqual(inverter_module.inverter_string("estrutura de dados"), "sodad ed aruturtse")
# AssertionError: '.osrevinu alO' != 'sodad ed aruturtse'
# - .osrevinu alO
# + sodad ed aruturtse
#
#
# ======================================================================
# FAIL: test_inverter_simples (__main__.TestListaDeExercicios)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-5-233e9ae035d0>", line 77, in test_inverter_simples
#     self.assertEqual(inverter_module.inverter_string("algoritmo"), "omtirgola")
# AssertionError: '.osrevinu alO' != 'omtirgola'
# - .osrevinu alO
# + omtirgola
#
#
# ======================================================================
# FAIL: test_inverter_vazio (__main__.TestListaDeExercicios)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-5-233e9ae035d0>", line 83, in test_inverter_vazio
#     self.assertEqual(inverter_module.inverter_string(""), "")
# AssertionError: '.osrevinu alO' != ''
# - .osrevinu alO
# +
#
#
# ----------------------------------------------------------------------
# Ran 12 tests in 0.110s
#
# FAILED (failures=3, errors=3)
# A palavra é: .osrevinu alO
# A palavra é: .osrevinu alO
